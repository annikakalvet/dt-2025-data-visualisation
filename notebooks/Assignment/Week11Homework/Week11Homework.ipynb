# %%
import urllib.request
text=urllib.request.urlopen("https://raw.githubusercontent.com/annikakalvet/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/Assignment/Week11Homework/text.txt").read().decode("utf-8")
words=text.split(" ")
print (*words[:])
# Out:
# Pärandkeele mõistega sarnanevad paljud teised mõisted, mis ei ole aga tähenduslikult samad. Teine keel, emakeel, põliskeel ja võõrkeel tähistavad kõik kindlal viisil omandatud keelt. Pärandkeel on aga keel, mille laps on omandanud üldjuhul sisserännanud vanematelt. Seega ei ole pärandkeel riigikeel või , vaid ühiskonnast erinev kodukeel. Eestis räägitakse pärandkeeltena enim vene, ukraina ja soome keelt. Pärandkeelte kasutus väheneb põlvkonniti, kui välisriigi keel saab järgmise põlvkonna emakeeleks ja pärandkeel hääbub. Pärandkeeleks ei saa aga pidada põliskeeli, nagu näiteks võru keelt, kuna kõnelejad on juba sündinud Eestis ning aja jooksul on see kujunenud enamuskeeleks. Eesti keel on pärandkeelena mõjutatud riikidest, kus inimene seda kasutab, ning kogukonna suurusest. Näiteks Ameerikas sündinud laps räägib küll vanematelt õpitud eesti keelt, kuid võib seda teha kerge foneetilise või grammatilise eripäraga (inglise keelele omane "r" või umbisikulise kõneviisi kasutamine). Samuti
# ...

# %% [markdown]
# Task 1. Printing the whole text which I uploaded to GitHub, making it into readable text.

# %%
import urllib.request
text=urllib.request.urlopen("https://raw.githubusercontent.com/annikakalvet/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/Assignment/Week11Homework/text.txt").read().decode("utf-8")
words=text.split(" ")
print (*words[:30])
# Out:
# Pärandkeele mõistega sarnanevad paljud teised mõisted, mis ei ole aga tähenduslikult samad. Teine keel, emakeel, põliskeel ja võõrkeel tähistavad kõik kindlal viisil omandatud keelt. Pärandkeel on aga keel, mille laps

# %% [markdown]
# Task 2. Printing the first 30 words.

# %%
import urllib.request
text=urllib.request.urlopen("https://raw.githubusercontent.com/annikakalvet/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/Assignment/Week11Homework/text.txt").read().decode("utf-8")
words=text.split(" ")
firstWord=words[:1]
for letter in firstWord:
    print(letter)
# Out:
# Pärandkeele

# %% [markdown]
# Task 3. This one prints the first word of all the words, by understanding to separate the text by spaces.

# %%
import urllib.request
text=urllib.request.urlopen("https://raw.githubusercontent.com/annikakalvet/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/Assignment/Week11Homework/text.txt").read().decode("utf-8")
words=text.split(". ")
firstsentence=words[:1]
lastsentence=words[12:]
print("The first sentence:",*firstsentence)
print ("The last sentence:", *lastsentence)
# Out:
# The first sentence: Pärandkeele mõistega sarnanevad paljud teised mõisted, mis ei ole aga tähenduslikult samad
# The last sentence: Mida rohkem levib eesti keel pärandkeelena, seda kestlikumaks see keelt teeb

# %% [markdown]
# Task 4. This one splits the text by dots, meaning by sentences. Then it understands that the first sentence includes the first words which end with a dot (same for the last sentence). Then it prints the first and last sentence.

# %%
pip install WordCloud
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import urllib.request #use to work with url-s
text=urllib.request.urlopen("https://raw.githubusercontent.com/annikakalvet/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/Assignment/Week11Homework/text.txt").read().decode("utf-8") #convert the text to a readable format (last one)
words=text.split(" ")
print(*words[:50])
WordCloud().generate_from_text(text).to_image()
# Out:
# Pärandkeele mõistega sarnanevad paljud teised mõisted, mis ei ole aga tähenduslikult samad. Teine keel, emakeel, põliskeel ja võõrkeel tähistavad kõik kindlal viisil omandatud keelt. Pärandkeel on aga keel, mille laps on omandanud üldjuhul sisserännanud vanematelt. Seega ei ole pärandkeel riigikeel või , vaid ühiskonnast erinev kodukeel. Eestis räägitakse pärandkeeltena enim
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# Task 5. Generating wordcloud from the first 50 words from the text.

# %%
from wordcloud import WordCloud
from PIL import Image 
import urllib.request 
import numpy as np 
text2=urllib.request.urlopen("https://raw.githubusercontent.com/annikakalvet/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/Assignment/Week11Homework/text.txt").read().decode("utf-8") #convert the text to a readable format (last one)
words=text.split(" ")
img=urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=1bkSZHxaK3rgcJGoAoobMUAs0QjZS2XGM","image1.png")
WordCloud(mask=np.array(Image.open("image1.png")), background_color="white").generate_from_text(text2).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=739x731>

# %% [markdown]
# Task 6. This generates word cloud from the text, sees the shape of the image and keeps the word cloud in the same shape.
